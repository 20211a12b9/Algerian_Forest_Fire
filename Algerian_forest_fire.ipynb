# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv")

# %%
df.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           32   71   12    0.7  57.1  2.5   8.2  0.6  2.8
# 1    2      6  2012           30   73   13    4.0  55.7  2.7   7.8  0.6  2.9
# 2    3      6  2012           29   80   14    2.0  48.7  2.2   7.6  0.3  2.6
# 3    4      6  2012           30   64   14    0.0  79.4  5.2  15.4  2.2  5.6
# 4    5      6  2012           32   60   14    0.2  77.1  6.0  17.6  1.8  6.5
#
#    FWI    Classes
# 0  0.2  not fire
# 1  0.2  not fire
# 2  0.1  not fire
# 3    1  not fire
# 4  0.9  not fire

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# dtype: int64

# %%
[f for f in df.columns if(df[f].isnull().sum()>0)]
# Out:
# ['Classes  ']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    object
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    object
#  13  Classes      121 non-null    object
# dtypes: float64(5), int64(6), object(3)
# memory usage: 13.5+ KB

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  122.000000  122.000000   122.0   122.000000  122.000000  122.000000
# mean    15.754098    7.500000  2012.0    33.163934   55.901639   15.008197
# std      8.843274    1.115259     0.0     3.675608   15.716186    2.692186
# min      1.000000    6.000000  2012.0    24.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   43.250000   14.000000
# 50%     16.000000    7.500000  2012.0    34.000000   56.000000   15.000000
# 75%     23.000000    8.000000  2012.0    36.000000   66.750000   16.750000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#             Rain         FFMC         DMC         ISI         BUI
# count  122.000000  122.000000  122.000000  122.000000  122.000000
# mean     0.678689   81.102459   17.031967    5.892623   17.903279
# std      1.486759   12.244064   12.995068    4.832913   13.878868
# ...

# %%
df.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
#  RH              int64
#  Ws              int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC              object
# ISI            float64
# BUI            float64
# FWI             object
# Classes         object
# dtype: object

# %%
df.shape
# Out:
# (122, 14)

# %%
dff=pd.read_csv("Bejaia Region ForestFire Dataset.csv")

# %%
dff.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI    Classes
# 0  0.5  not fire
# 1  0.4  not fire
# 2  0.1  not fire
# 3  0.0  not fire
# 4  0.5  not fire

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    float64
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    float64
#  13  Classes      122 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 13.5+ KB

# %%
df.shape
# Out:
# (122, 14)

# %%
dff.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  122.000000  122.000000   122.0   122.000000  122.000000  122.000000
# mean    15.754098    7.500000  2012.0    31.180328   67.975410   16.000000
# std      8.843274    1.115259     0.0     3.320401   11.154411    2.848807
# min      1.000000    6.000000  2012.0    22.000000   45.000000   11.000000
# 25%      8.000000    7.000000  2012.0    29.000000   60.000000   14.000000
# 50%     16.000000    7.500000  2012.0    31.000000   68.000000   16.000000
# 75%     23.000000    8.000000  2012.0    34.000000   77.750000   18.000000
# max     31.000000    9.000000  2012.0    37.000000   89.000000   26.000000
#
#             Rain         FFMC         DMC          DC         ISI         BUI  \
# count  122.000000  122.000000  122.000000  122.000000  122.000000  122.000000
# mean     0.842623   74.672951   12.314754   53.160656    3.655738   15.426230
# ...

# %%
dff.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
#  RH              int64
#  Ws              int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# dtype: object

# %%
dff.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
d=pd.read_csv("Sidi-Bel Abbes Region ForestFire Dataset.csv")

# %%
d.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           32   71   12    0.7  57.1  2.5   8.2  0.6  2.8
# 1    2      6  2012           30   73   13    4.0  55.7  2.7   7.8  0.6  2.9
# 2    3      6  2012           29   80   14    2.0  48.7  2.2   7.6  0.3  2.6
# 3    4      6  2012           30   64   14    0.0  79.4  5.2  15.4  2.2  5.6
# 4    5      6  2012           32   60   14    0.2  77.1  6.0  17.6  1.8  6.5
#
#    FWI    Classes
# 0  0.2  not fire
# 1  0.2  not fire
# 2  0.1  not fire
# 3    1  not fire
# 4  0.9  not fire

# %%
dff.shape
# Out:
# (122, 14)

# %%
d.shape
# Out:
# (122, 14)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
dff.columns=df.columns.str.strip()

# %%
dff.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
dff.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
# RH               int64
# Ws               int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# dtype: object

# %%
dff.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df=dff

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes
# 0  0.5  not fire
# 1  0.4  not fire
# 2  0.1  not fire
# 3  0.0  not fire
# 4  0.5  not fire

# %%
dff['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire '],
#       dtype=object)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes
# 0  0.5  not fire
# 1  0.4  not fire
# 2  0.1  not fire
# 3  0.0  not fire
# 4  0.5  not fire

# %%
df['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire '],
#       dtype=object)

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes
# 0  0.5        0
# 1  0.4        0
# 2  0.1        0
# 3  0.0        0
# 4  0.5        0

# %%
df.tail()
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 117   26      9  2012           31  54  11   0.0  82.0  6.0  16.3  2.5  6.2
# 118   27      9  2012           31  66  11   0.0  85.7  8.3  24.9  4.0  9.0
# 119   28      9  2012           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8
# 120   29      9  2012           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0
# 121   30      9  2012           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4
#
#      FWI  Classes
# 117  1.7        0
# 118  4.1        1
# 119  0.9        0
# 120  0.1        0
# 121  0.1        0

# %%
df['Classes'].value_counts()
# Out:
# 0    63
# 1    59
# Name: Classes, dtype: int64

# %%
df['Classes'].isnull().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
# RH               int64
# Ws               int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes          int32
# dtype: object

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 df.hist(bins=50,figsize=(20,15))
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
sns.barplot(x='month',y='Classes',data=df)
# Out:
# <Axes: xlabel='month', ylabel='Classes'>

# %%
df['month'].value_counts()
# Out:
# 7    31
# 8    31
# 6    30
# 9    30
# Name: month, dtype: int64

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
df.corr()
# Out:
#                       day         month  year  Temperature        RH  \
# day          1.000000e+00  5.358691e-17   NaN     0.181092 -0.210608
# month        5.358691e-17  1.000000e+00   NaN    -0.035708 -0.088025
# year                  NaN           NaN   NaN          NaN       NaN
# Temperature  1.810918e-01 -3.570824e-02   NaN     1.000000 -0.660151
# RH          -2.106080e-01 -8.802546e-02   NaN    -0.660151  1.000000
# Ws           6.396952e-02 -7.803641e-03   NaN    -0.228035  0.245774
# Rain        -9.748921e-02  1.451800e-01   NaN    -0.486947  0.329163
# FFMC         2.917513e-01 -4.074604e-02   NaN     0.748423 -0.653153
# DMC          5.427601e-01 -7.624391e-03   NaN     0.541489 -0.347080
# DC           5.686443e-01 -6.211283e-03   NaN     0.532838 -0.314271
# ISI          3.714887e-01 -1.128069e-02   NaN     0.663871 -0.586410
# BUI          5.573006e-01 -9.113001e-03   NaN     0.542210 -0.338233
# FWI          4.675849e-01  3.329551e-03   NaN     0.608367 -0.476067
# ...

# %%
sns.heatmap(data=df.corr())
# Out:
# <Axes: >

# %%
sns.countplot(x='month',hue='Classes',data=df)
mlt.xlabel('monnth')
mlt.ylabel('No of fores')
# Out:
# Text(0, 0.5, 'No of fores')

# %%
sns.boxplot(df['FWI'],orient="h",color='red')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
df['year'].unique()
# Out:
# array([2012], dtype=int64)

# %%
df.drop('year',axis=1,inplace=True)

# %%
df['month'].unique()
# Out:
# array([6, 7, 8, 9], dtype=int64)

# %%
df.drop('month',axis=1,inplace=True)

# %%
sns.countplot(x='day',hue='Classes',data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
df.drop('day',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes'],
#       dtype='object')

# %%
sns.countplot(x='Temperature',hue='Classes',data=df)
# Out:
# <Axes: xlabel='Temperature', ylabel='count'>

# %%
sns.pairplot(df,height=2.5)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0

# %%
X=df.drop('FWI',axis=1)
y=df['FWI']

# %%
X
# Out:
#      Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes
# 0             29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0
# 1             29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0
# 2             26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0
# 3             25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0
# 4             27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0
# ..           ...  ..  ..   ...   ...  ...   ...  ...  ...      ...
# 117           31  54  11   0.0  82.0  6.0  16.3  2.5  6.2        0
# 118           31  66  11   0.0  85.7  8.3  24.9  4.0  9.0        1
# 119           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8        0
# 120           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0        0
# 121           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4        0
#
# [122 rows x 10 columns]

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 117    1.7
# 118    4.1
# 119    0.9
# 120    0.1
# 121    0.1
# Name: FWI, Length: 122, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((91, 10), (31, 10))

# %% [markdown]
# # Feature Scaling Or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.73323558,  1.90224414, -1.01880763, -0.06007241, -2.44466934,
#         -0.97491305, -0.91742766, -1.26992877, -0.94840982, -1.05654109],
#        [ 1.17317692, -1.58553965, -1.01880763, -0.2232542 ,  0.40445483,
#          0.2313547 ,  0.38198652, -0.42664566,  0.30563348, -1.05654109],
#        [ 0.21997067, -0.57591803,  0.80622178, -0.30484509,  0.4107582 ,
#         -0.41083101, -0.14547939, -0.15679506, -0.31799886,  0.94648472],
#        [-1.68644182,  1.16797387,  1.90123943,  2.02049531, -1.65674784,
#         -0.86209664, -0.9155026 , -1.13500348, -0.89418092, -1.05654109],
#        [-1.05097099,  1.07619008,  1.90123943,  6.50799431, -1.41091632,
#         -0.36744009, -0.89625202, -1.06754083, -0.53491446, -1.05654109],
#        [ 1.49091234, -1.40197209,  0.07621002, -0.34564053,  0.92133134,
#          2.14055545,  2.04523666,  2.238129  ,  2.12230162,  0.94648472],
#        [-0.73323558, -0.02521533,  1.17122767,  0.06231392, -0.94446679,
# ...

# %% [markdown]
# # Box Plots To understand Effect Of Standard Scaler

# %%
mlt.subplots(figsize=(15, 5))
mlt.subplot(1, 2, 1)
sns.boxplot(data=X_train)
mlt.title('X_train Before Scaling')
mlt.subplot(1, 2, 2)
sns.boxplot(data=X_train_scaled)
mlt.title('X_train After Scaling')
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_20880\3830901814.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   mlt.subplot(1, 2, 1)
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# ### what is mean_absolute_error(MAE)
# MAE measures the average absolute difference between the predicted values and the actual (ground truth) values and providing a clear measure of the model's accuracy.

# %% [markdown]
# ### what is R2 score
# The R2 score is a useful metric for understanding how well a regression model fits the data, with higher values indicating better fit, but it should be used in conjunction with other evaluation techniques for a comprehensive assessment of model performance.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred=linreg.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
mlt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.5057636127909892
# R2 Score 0.9848289250067759

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
mlt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 1.180976777264699
# R2 Score 0.9306697914180669

# %% [markdown]
# ### Ridge Regression model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
mlt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.5013396747321338
# R2 Score 0.9826727506209474

# %%
dff.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0

# %%
x1=dff.drop('Classes',axis=1)
y1=df['Classes']

# %%
from sklearn.model_selection import train_test_split


# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size=0.3, random_state=42)

# %% [markdown]
# # XGB Classifier

# %%
from  sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Create the individual classifiers

model = GradientBoostingClassifier(random_state=42)



# Fit the Voting Classifier on the training data
model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.918918918918919

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93        24
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.92        37
#    macro avg       0.91      0.94      0.91        37
# weighted avg       0.93      0.92      0.92        37

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[21,  3],
#        [ 0, 13]], dtype=int64)
